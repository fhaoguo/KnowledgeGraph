# %% [markdown]
# # 基于wordnet构建英语知识图谱

# %%
import nltk
from nltk.corpus import wordnet

# %% [markdown]
# ## 1. 关系抽取

# %% [markdown]
# ### 1.1 Helpers

# %%
def index_relationship(start, end, rel_type):
    '''
    索引关系
    '''
    relationship_index.setdefault(start, {})
    relationship_index[start].setdefault(end, {})
    relationship_index[start][end].append(rel_type)

# %%
def add_relationship(start, end, rel_type):
    '''
    添加关系，移除重复关系
    '''
    if (start in relationship_index and end in relationship_index[start] and rel_type in relationship_index[start][end]) or \
       (end in relationship_index and start in relationship_index[end] and rel_type in relationship_index[end][start]):
        pass
    else:
        index_relationship(start, end, rel_type)
        index_relationship(end, start, rel_type)
        relationships.append([start, end, rel_type])

# %%
def extract_relationships(synset):
    '''
    关系抽取，
    '''
    # 上位概念（名词，动词）
    for related_node in synset.hypernyms():
        add_relationship(synset.name(), related_node.name(), 'IsA')
    # 下位概念（名词，动词）
    for related_node in synset.hyponyms():
        add_relationship(related_node.name(), synset.name(), 'IsA')
    # 上位整体概念（名词）
    for related_node in synset.member_holonyms():
        add_relationship(synset.name(), related_node.name(), 'PartOf')
    for related_node in synset.substance_holonyms():
        add_relationship(synset.name(), related_node.name(), 'PartOf')
    for related_node in synset.part_holonyms():
        add_relationship(synset.name(), related_node.name(), 'PartOf')
    # 下位部件概念（名词）
    for related_node in synset.member_meronyms():
        add_relationship(related_node.name(), synset.name(), 'PartOf')
    for related_node in synset.substance_meronyms():
        add_relationship(related_node.name(), synset.name(), 'PartOf')
    for related_node in synset.part_meronyms():
        add_relationship(related_node.name(), synset.name(), 'PartOf')
    # 主题域（名词，动词）
    # topic_domains
    for related_node in synset.topic_domains():
        add_relationship(synset.name(), related_node.name(), 'Domain')
    # region_domains
    for related_node in synset.region_domains():
        add_relationship(synset.name(), related_node.name(), 'Domain')
    # usage_domains
    for related_node in synset.usage_domains():
        add_relationship(synset.name(), related_node.name(), 'Domain')
    # 属性
    for related_node in synset.attributes():
        add_relationship(synset.name(), related_node.name(), 'Attribute')
    # 因果
    for related_node in synset.causes():
        add_relationship(synset.name(), related_node.name(), 'Cause')
    # similar_tos
    for related_node in synset.similar_tos():
        add_relationship(synset.name(), related_node.name(), 'SimilarTo')
    # 反义（形容词）
    for lemma in synset.lemmas():
        for related_node in lemma.antonyms():
            add_relationship(synset.name(), related_node.name(), 'Antonym')
    # entailment（动词），先不添加该关系

# %%
def extract_lemmas(synset):
    '''
    实体抽取
    '''
    pass

# %%
all_synsets = list(nltk.corpus.wordnet.all_synsets())
all_synsets
# Out:
# [Synset('able.a.01'),
#  Synset('unable.a.01'),
#  Synset('abaxial.a.01'),
#  Synset('adaxial.a.01'),
#  Synset('acroscopic.a.01'),
#  Synset('basiscopic.a.01'),
#  Synset('abducent.a.01'),
#  Synset('adducent.a.01'),
#  Synset('nascent.a.01'),
#  Synset('emergent.s.02'),
#  Synset('dissilient.s.01'),
#  Synset('parturient.s.02'),
#  Synset('dying.a.01'),
#  Synset('moribund.s.02'),
#  Synset('last.s.05'),
#  Synset('abridged.a.01'),
#  Synset('cut.s.03'),
#  Synset('half-length.s.02'),
#  Synset('potted.s.03'),
#  Synset('unabridged.a.01'),
#  Synset('full-length.s.02'),
#  Synset('absolute.a.01'),
#  Synset('direct.s.10'),
#  Synset('implicit.s.02'),
#  Synset('infinite.s.04'),
#  Synset('living.s.03'),
#  Synset('relative.a.01'),
#  Synset('relational.s.01'),
#  Synset('absorbent.a.01'),
#  Synset('absorbefacient.s.01'),
#  Synset('assimilating.s.01'),
#  Synset('hygroscopic.s.01'),
#  Synset('receptive.s.04'),
#  Synset('shock-absorbent.s.01'),
#  Synset('spongy.s.02'),
#  Synset('thirsty.s.04'),
#  Synset('nonabsorbent.a.01'),
#  Synset('repellent.s.03'),
#  Synset('adsorbent.a.01'),
#  Synset('chemisorptive.s.01'),
#  Synset('nonadsorbent.a.01'),
#  Synset('absorbable.a.01'),
#  Synset('adsorbable.a.01'),
#  Synset('abstemious.a.01'),
#  Synset('abstinent.s.01'),
#  Synset('ascetic.s.02'),
#  Synset('gluttonous.a.01'),
#  Synset('crapulous.s.02'),
#  Synset('crapulent.s.01'),
#  Synset('edacious.s.01'),
#  Synset('greedy.s.03'),
#  Synset('hoggish.s.01'),
#  Synset('overgreedy.s.01'),
#  Synset('abstract.a.01'),
#  Synset('conceptional.s.01'),
#  Synset('conceptual.s.01'),
#  Synset('ideal.s.02'),
#  Synset('ideological.s.02'),
#  Synset('concrete.a.01'),
#  Synset('objective.s.04'),
#  Synset('real.s.04'),
#  Synset('abundant.a.01'),
#  Synset('abounding.s.01'),
#  Synset('ample.s.02'),
#  Synset('copious.s.01'),
#  Synset('easy.s.12'),
#  Synset('exuberant.s.03'),
#  Synset('thick.s.10'),
#  Synset('long.s.09'),
#  Synset('overabundant.s.01'),
#  Synset('plentiful.s.01'),
#  Synset('rampant.s.03'),
#  Synset('rank.s.05'),
#  Synset('superabundant.s.01'),
#  Synset('teeming.s.01'),
#  Synset('torrential.s.03'),
#  Synset('verdant.s.01'),
#  Synset('scarce.a.01'),
#  Synset('rare.s.03'),
#  Synset('tight.s.06'),
#  Synset('abused.a.02'),
#  Synset('battered.s.03'),
#  Synset('unabused.a.01'),
#  Synset('acceptable.a.01'),
#  Synset('bankable.s.02'),
#  Synset('unexceptionable.s.01'),
#  Synset('unobjectionable.s.03'),
#  Synset('unacceptable.a.02'),
#  Synset('exceptionable.s.01'),
#  Synset('accessible.a.01'),
#  Synset('approachable.s.03'),
#  Synset('come-at-able.s.02'),
#  Synset('handy.s.01'),
#  Synset('inaccessible.a.01'),
#  Synset('outback.s.01'),
#  Synset('pathless.s.01'),
#  Synset('unapproachable.s.02'),
#  Synset('un-come-at-able.s.01'),
#  Synset('accommodating.a.01'),
#  Synset('complaisant.s.01'),
#  Synset('unaccommodating.a.01'),
#  Synset('disobliging.s.01'),
#  Synset('accurate.a.01'),
#  Synset('close.s.05'),
#  Synset('dead-on.s.01'),
#  Synset('high-fidelity.s.01'),
#  Synset('surgical.s.03'),
#  Synset('straight.s.05'),
#  Synset('true.s.02'),
#  Synset('veracious.s.02'),
#  Synset('inaccurate.a.01'),
#  Synset('away.s.03'),
#  Synset('faulty.s.02'),
#  Synset('unfaithful.s.04'),
#  Synset('wide.s.07'),
#  Synset('accustomed.a.01'),
#  Synset('used_to.s.01'),
#  Synset('unaccustomed.a.01'),
#  Synset('new.s.11'),
#  Synset('unused.s.04'),
#  Synset('acidic.a.01'),
#  Synset('acid.s.03'),
#  Synset('acid-forming.s.01'),
#  Synset('alkaline.a.01'),
#  Synset('alkalescent.s.01'),
#  Synset('basic.s.04'),
#  Synset('base-forming.s.01'),
#  Synset('saltlike.s.01'),
#  Synset('amphoteric.a.01'),
#  Synset('acid-loving.a.01'),
#  Synset('acidophilic.s.01'),
#  Synset('alkaline-loving.a.01'),
#  Synset('acknowledged.a.01'),
#  Synset('accepted.s.01'),
#  Synset('self-confessed.s.01'),
#  Synset('assumptive.s.02'),
#  Synset('declarable.s.01'),
#  Synset('given.s.01'),
#  Synset('putative.s.01'),
#  Synset('unacknowledged.a.01'),
#  Synset('unappreciated.s.02'),
#  Synset('unavowed.s.03'),
#  Synset('unconfessed.s.01'),
#  Synset('unrecognized.s.01'),
#  Synset('acquisitive.a.01'),
#  Synset('accumulative.s.02'),
#  Synset('avaricious.s.01'),
#  Synset('possessive.s.02'),
#  Synset('plundering.s.01'),
#  Synset('predaceous.s.02'),
#  Synset('rapacious.s.02'),
#  Synset('sordid.s.04'),
#  Synset('unacquisitive.a.01'),
#  Synset('acropetal.a.01'),
#  Synset('basipetal.a.01'),
#  Synset('active.a.05'),
#  Synset('about.s.01'),
#  Synset('acrobatic.s.01'),
#  Synset('agile.s.01'),
#  Synset('hot.s.21'),
#  Synset('hyperactive.s.01'),
#  Synset('on_the_go.s.01'),
#  Synset('sporty.s.03'),
#  Synset('inactive.a.09'),
#  Synset('desk-bound.s.01'),
#  Synset('abeyant.s.01'),
#  Synset('hypoactive.s.01'),
#  Synset('inert.s.03'),
#  Synset('sedentary.s.01'),
#  Synset('active.a.14'),
#  Synset('activated.s.04'),
#  Synset('inactive.a.08'),
#  Synset('off.s.05'),
#  Synset('retired.s.01'),
#  Synset('active.a.07'),
#  Synset('brisk.s.03'),
#  Synset('bustling.s.01'),
#  Synset('busy.s.04'),
#  Synset('going.s.01'),
#  Synset('open.s.21'),
#  Synset('springy.s.02'),
#  Synset('inactive.a.07'),
#  Synset('dark.s.11'),
#  Synset('dead.s.17'),
#  Synset('dull.s.08'),
#  Synset('idle.s.03'),
#  Synset('strikebound.s.01'),
#  Synset('active.a.01'),
#  Synset('progressive.s.06'),
#  Synset('inactive.a.02'),
#  Synset('dead-end.s.01'),
#  Synset('flat.s.15'),
#  Synset('indolent.s.02'),
#  Synset('latent.s.02'),
#  Synset('quiescent.s.04'),
#  Synset('active.a.03'),
#  Synset('activist.s.01'),
#  Synset('hands-on.s.01'),
#  Synset('proactive.s.02'),
#  Synset('passive.a.01'),
#  Synset('hands-off.s.01'),
#  Synset('resistless.s.02'),
#  Synset('active.a.13'),
#  Synset('eruptive.s.03'),
#  Synset('dormant.a.02'),
#  Synset('quiescent.s.03'),
#  Synset('extinct.a.02'),
#  Synset('dead.s.05'),
#  Synset('active.a.12'),
#  Synset('alive.s.07'),
#  Synset('active.a.11'),
#  Synset('stative.a.01'),
#  Synset('active.a.10'),
#  Synset('passive.a.03'),
#  Synset('active.a.06'),
#  Synset('activated.s.03'),
#  Synset('counteractive.s.01'),
#  Synset('surface-active.s.01'),
#  Synset('inactive.a.04'),
#  Synset('quiescent.s.01'),
#  Synset('active.a.09'),
#  Synset('quiet.a.06'),
#  Synset('actual.a.01'),
#  Synset('effective.s.05'),
#  Synset('potential.a.01'),
#  Synset('latent.s.01'),
#  Synset('acute.a.01'),
#  Synset('subacute.s.01'),
#  Synset('chronic.a.01'),
#  Synset('degenerative.s.01'),
#  Synset('virulent.a.02'),
#  Synset('highly_infective.s.01'),
#  Synset('deadly.s.06'),
#  Synset('avirulent.a.01'),
#  Synset('adaptive.a.01'),
#  Synset('accommodative.s.03'),
#  Synset('adaptational.s.01'),
#  Synset('adjustive.s.01'),
#  Synset('maladaptive.a.01'),
#  Synset('dysfunctional.s.02'),
#  Synset('maladjustive.s.01'),
#  Synset('addicted.a.01'),
#  Synset('alcoholic.s.02'),
#  Synset('dependent.s.06'),
#  Synset('unaddicted.a.01'),
#  Synset('clean.s.18'),
#  Synset('addictive.a.01'),
#  Synset('nonaddictive.a.01'),
#  Synset('additive.a.02'),
#  Synset('accumulative.s.01'),
#  Synset('addable.s.01'),
#  Synset('extra.s.03'),
#  Synset('complemental.s.01'),
#  Synset('incremental.s.01'),
#  Synset('intercalary.s.01'),
#  Synset('summational.s.01'),
#  Synset('supplementary.s.02'),
#  Synset('subtractive.a.01'),
#  Synset('ablative.s.02'),
#  Synset('reductive.s.01'),
#  Synset('addressed.a.01'),
#  Synset('self-addressed.s.01'),
#  Synset('unaddressed.a.01'),
#  Synset('adequate.a.01'),
#  Synset('adequate_to.s.01'),
#  Synset('competent.s.02'),
#  Synset('inadequate.a.01'),
#  Synset('deficient.s.01'),
#  Synset('incapable.s.04'),
#  Synset('short-handed.s.01'),
#  Synset('adhesive.a.01'),
#  Synset('adherent.s.01'),
#  Synset('agglutinate.s.01'),
#  Synset('bondable.s.02'),
#  Synset('coherent.s.04'),
#  Synset('cohesive.s.01'),
#  Synset('gluey.s.01'),
#  Synset('gooey.s.01'),
#  Synset('gum-like.s.01'),
#  Synset('gummed.s.01'),
#  Synset('pitchy.s.02'),
#  Synset('self-sealing.s.02'),
#  Synset('stick-on.s.01'),
#  Synset('sticky.s.05'),
#  Synset('nonadhesive.a.01'),
#  Synset('nonglutinous.s.01'),
#  Synset('nonresinous.s.01'),
#  Synset('ungummed.s.01'),
#  Synset('adjective.a.02'),
#  Synset('substantive.a.02'),
#  Synset('adoptable.a.01'),
#  Synset('unadoptable.a.01'),
#  Synset('adorned.a.01'),
#  Synset('beady.s.02'),
#  Synset('bedaubed.s.01'),
#  Synset('bespectacled.s.01'),
#  Synset('brocaded.s.01'),
#  Synset('buttony.s.02'),
#  Synset('carbuncled.s.02'),
#  Synset('champleve.s.01'),
#  Synset('clinquant.s.01'),
#  Synset('crested.s.03'),
#  Synset('crested.s.02'),
#  Synset('crested.s.01'),
#  Synset('crocketed.s.01'),
#  Synset('feathery.s.03'),
#  Synset('frilled.s.01'),
#  Synset('fringed.s.02'),
#  Synset('gilt-edged.s.02'),
#  Synset('inflamed.s.03'),
#  Synset('inlaid.s.01'),
#  Synset('inwrought.s.01'),
#  Synset('tessellated.s.02'),
#  Synset('mounted.s.02'),
#  Synset('paneled.s.01'),
#  Synset('studded.s.01'),
#  Synset('tapestried.s.01'),
#  Synset('tasseled.s.01'),
#  Synset('tricked-out.s.01'),
#  Synset('tufted.s.02'),
#  Synset('unadorned.a.01'),
#  Synset('plain.s.06'),
#  Synset('untufted.s.01'),
#  Synset('cholinergic.a.01'),
#  Synset('anticholinergic.a.01'),
#  Synset('adroit.a.01'),
#  Synset('clean.s.17'),
#  Synset('clever.s.03'),
#  Synset('coordinated.s.02'),
#  Synset('deft.s.01'),
#  Synset('handy.s.03'),
#  Synset('light-fingered.s.01'),
#  Synset('quick-witted.s.01'),
#  Synset('maladroit.a.01'),
#  Synset('bumbling.s.01'),
#  Synset('inept.s.03'),
#  Synset('uncoordinated.s.02'),
#  Synset('unmechanical.s.01'),
#  Synset('advantageous.a.01'),
#  Synset('beneficial.s.01'),
#  Synset('plus.s.02'),
#  Synset('discriminatory.s.04'),
#  Synset('disadvantageous.a.01'),
#  Synset('minus.s.02'),
#  Synset('adventurous.a.01'),
#  Synset('audacious.s.03'),
#  Synset('sporting.s.03'),
#  Synset('swaggering.s.02'),
#  Synset('unadventurous.a.01'),
#  Synset('safe.s.02'),
#  Synset('advisable.a.01'),
#  Synset('better.s.03'),
#  Synset('well.s.03'),
#  Synset('inadvisable.a.01'),
#  Synset('well-advised.a.01'),
#  Synset('considered.s.01'),
#  Synset('ill-advised.a.01'),
#  Synset('aerobic.a.01'),
#  Synset('aerobiotic.s.01'),
#  Synset('oxidative.s.01'),
#  Synset('anaerobic.a.01'),
#  Synset('aerobic.a.02'),
#  Synset('anaerobic.a.02'),
#  Synset('aesthetic.a.02'),
#  Synset('artistic.s.02'),
#  Synset('cosmetic.s.02'),
#  Synset('painterly.s.01'),
#  Synset('sensuous.s.01'),
#  Synset('inaesthetic.a.01'),
#  Synset('inartistic.s.01'),
#  Synset('affected.a.01'),
#  Synset('impressed.s.01'),
#  Synset('smitten.s.01'),
#  Synset('stage-struck.s.01'),
#  Synset('subject.s.03'),
#  Synset('taken.s.02'),
#  Synset('wonder-struck.s.01'),
#  Synset('unaffected.a.01'),
#  Synset('immune.s.04'),
#  Synset('superior.s.07'),
#  Synset('unimpressed.s.01'),
#  Synset('uninfluenced.s.01'),
#  Synset('affected.a.02'),
#  Synset('agonistic.s.03'),
#  Synset('artificial.s.02'),
#  Synset('constrained.s.01'),
#  Synset('elocutionary.s.02'),
#  Synset('mannered.s.01'),
#  Synset('plummy.s.02'),
#  Synset('unaffected.a.04'),
#  Synset('lifelike.s.02'),
#  Synset('unmannered.s.02'),
#  Synset('unselfconscious.s.01'),
#  Synset('unstilted.s.01'),
#  Synset('affirmative.a.01'),
#  Synset('assentient.s.01'),
#  Synset('negative.a.02'),
#  Synset('dissentient.s.02'),
#  Synset('acceptive.a.01'),
#  Synset('accepting.s.01'),
#  Synset('rejective.a.01'),
#  Synset('dismissive.s.02'),
#  Synset('repudiative.s.01'),
#  Synset('afloat.a.02'),
#  Synset('adrift.s.02'),
#  Synset('floating.s.01'),
#  Synset('waterborne.s.02'),
#  Synset('aground.a.01'),
#  Synset('afraid.a.01'),
#  Synset('acrophobic.s.01'),
#  Synset('afeard.s.01'),
#  Synset('aghast.s.01'),
#  Synset('agoraphobic.s.01'),
#  Synset('alarmed.s.01'),
#  Synset('algophobic.s.01'),
#  Synset('apprehensive.s.03'),
#  Synset('hangdog.s.02'),
#  Synset('claustrophobic.s.02'),
#  Synset('fearful.s.01'),
#  Synset('frightened.s.01'),
#  Synset('horrified.s.01'),
#  Synset('hunted.s.01'),
#  Synset('hydrophobic.s.02'),
#  Synset('mysophobic.s.01'),
#  Synset('panicky.s.01'),
#  Synset('numb.s.03'),
#  Synset('shitless.s.01'),
#  Synset('terror-stricken.s.01'),
#  Synset('triskaidekaphobic.s.01'),
#  Synset('unnerved.s.01'),
#  Synset('white-lipped.s.01'),
#  Synset('xenophobic.s.01'),
#  Synset('unafraid.a.01'),
#  Synset('unapprehensive.s.01'),
#  Synset('unblinking.s.02'),
#  Synset('unfrightened.s.01'),
#  Synset('aggressive.a.01'),
#  Synset('battleful.s.01'),
#  Synset('competitive.s.03'),
#  Synset('hard-hitting.s.02'),
#  Synset('hostile.s.05'),
#  Synset('in-your-face.s.01'),
#  Synset('obstreperous.s.02'),
#  Synset('predatory.s.02'),
#  Synset('pugnacious.s.02'),
#  Synset('scrappy.s.01'),
#  Synset('truculent.s.01'),
#  Synset('unaggressive.a.01'),
#  Synset('low-pressure.s.01'),
#  Synset('agitated.a.01'),
#  Synset('aroused.s.06'),
#  Synset('distraught.s.01'),
#  Synset('jolted.s.02'),
#  Synset('feverish.s.01'),
#  Synset('frantic.s.01'),
#  Synset('hysterical.s.02'),
#  Synset('psychedelic.s.03'),
#  Synset('wild-eyed.s.01'),
#  Synset('unagitated.a.02'),
#  Synset('agitated.a.02'),
#  Synset('churning.s.02'),
#  Synset('churning.s.01'),
#  Synset('jolted.s.01'),
#  Synset('rippled.s.02'),
#  Synset('seething.s.01'),
#  Synset('stirred.s.03'),
#  Synset('unagitated.a.01'),
#  Synset('nonturbulent.s.01'),
#  Synset('unstirred.s.01'),
#  Synset('agreeable.a.01'),
#  Synset('disagreeable.a.01'),
#  Synset('annoying.s.01'),
#  Synset('harsh.s.06'),
#  Synset('nerve-racking.s.01'),
#  Synset('unsweet.s.02'),
#  Synset('air-to-surface.a.01'),
#  Synset('air-to-air.a.01'),
#  Synset('surface-to-air.a.01'),
#  Synset('alert.a.01'),
#  Synset('argus-eyed.s.02'),
#  Synset('fly.s.01'),
#  Synset('heads-up.s.01'),
#  Synset('lidless.s.03'),
#  Synset('unalert.a.01'),
#  Synset('algorithmic.a.01'),
#  Synset('recursive.s.01'),
#  Synset('heuristic.a.01'),
#  Synset('trial-and-error.s.02'),
#  Synset('alienable.a.01'),
#  Synset('appropriable.s.01'),
#  Synset('assignable.s.01'),
#  Synset('inalienable.a.01'),
#  Synset('absolute.s.05'),
#  Synset('non-negotiable.s.01'),
#  Synset('nontransferable.s.01'),
#  Synset('alive.a.01'),
#  Synset('liveborn.s.01'),
#  Synset('viable.s.02'),
#  Synset('vital.s.04'),
#  Synset('dead.a.01'),
#  Synset('asleep.s.03'),
#  Synset('assassinated.s.01'),
#  Synset('bloodless.s.01'),
#  Synset('brain_dead.s.01'),
#  Synset('breathless.s.03'),
#  Synset('cold.s.13'),
#  Synset('d.o.a..s.01'),
#  Synset('deathlike.s.01'),
#  Synset('defunct.s.02'),
#  Synset('doomed.s.01'),
#  Synset('executed.s.01'),
#  Synset('fallen.s.04'),
#  Synset('late.s.04'),
#  Synset('lifeless.s.01'),
#  Synset('murdered.s.01'),
#  Synset('nonviable.s.01'),
#  Synset('slain.s.01'),
#  Synset('stillborn.s.02'),
#  Synset('stone-dead.s.01'),
#  Synset('apocrine.a.01'),
#  Synset('eccrine.a.01'),
#  Synset('artesian.a.01'),
#  Synset('subartesian.a.01'),
#  Synset('live.a.02'),
#  Synset('in_play.s.01'),
#  Synset('living.s.06'),
#  Synset('dead.a.02'),
#  Synset('extinct.s.03'),
#  Synset('lifeless.s.04'),
#  Synset('out_of_play.s.01'),
#  Synset('alphabetic.a.02'),
#  Synset('abecedarian.s.01'),
#  Synset('alphabetized.s.01'),
#  Synset('analphabetic.a.02'),
#  Synset('altricial.a.01'),
#  Synset('precocial.a.01'),
#  Synset('altruistic.a.01'),
#  Synset('egoistic.a.01'),
#  Synset('self-absorbed.s.01'),
#  Synset('ambiguous.a.02'),
#  Synset('double-barreled.s.02'),
#  Synset('double-edged.s.01'),
#  Synset('enigmatic.s.02'),
#  Synset('left-handed.s.05'),
#  Synset('multivalent.s.03'),
#  Synset('polysemous.s.01'),
#  Synset('uncertain.s.07'),
#  Synset('unambiguous.a.01'),
#  Synset('monosemous.s.01'),
#  Synset('ambitious.a.01'),
#  Synset('pushful.s.01'),
#  Synset('aspirant.s.01'),
#  Synset('compulsive.s.02'),
#  Synset('manque.s.01'),
#  Synset('overambitious.s.01'),
#  Synset('unambitious.a.01'),
#  Synset('shiftless.s.01'),
#  Synset('ametropic.a.01'),
#  Synset('emmetropic.a.01'),
#  Synset('ample.a.01'),
#  Synset('full.s.06'),
#  Synset('generous.s.03'),
#  Synset('wide.s.06'),
#  Synset('meager.a.01'),
#  Synset('bare.s.02'),
#  Synset('exiguous.s.01'),
#  Synset('hand-to-mouth.s.01'),
#  Synset('hardscrabble.s.01'),
#  Synset('measly.s.01'),
#  Synset('anabolic.a.02'),
#  Synset('constructive-metabolic.s.01'),
#  Synset('catabolic.a.02'),
#  Synset('destructive-metabolic.s.01'),
#  Synset('anaclinal.a.01'),
#  Synset('cataclinal.a.01'),
#  Synset('anastigmatic.a.02'),
#  Synset('astigmatic.a.01'),
#  Synset('anticlinal.a.01'),
#  Synset('synclinal.a.01'),
#  Synset('anadromous.a.01'),
#  Synset('catadromous.a.01'),
#  Synset('diadromous.a.01'),
#  Synset('anabatic.a.01'),
#  Synset('katabatic.a.01'),
#  Synset('anal.a.02'),
#  Synset('oral.a.04'),
#  Synset('analogue.a.01'),
#  Synset('digital.a.03'),
#  Synset('analytic.a.04'),
#  Synset('synthetic.a.04'),
#  Synset('analytic.a.03'),
#  Synset('isolating.s.01'),
#  Synset('synthetic.a.03'),
#  Synset('agglutinative.s.01'),
#  Synset('analytic.a.02'),
#  Synset('synthetic.a.02'),
#  Synset('inflectional.a.01'),
#  Synset('derivational.a.01'),
#  Synset('apocarpous.a.01'),
#  Synset('syncarpous.a.01'),
#  Synset('angry.a.01'),
#  Synset('aggravated.s.02'),
#  Synset('angered.s.01'),
#  Synset('black.s.03'),
#  Synset('choleric.s.03'),
#  Synset('hot_under_the_collar.s.01'),
#  Synset('huffy.s.02'),
#  Synset('indignant.s.01'),
#  Synset('irate.s.01'),
#  Synset('livid.s.03'),
#  Synset('smoldering.s.01'),
#  Synset('wrathful.s.01'),
#  Synset('unangry.a.01'),
#  Synset('resentful.a.01'),
#  Synset('acrimonious.s.01'),
#  Synset('rancorous.s.01'),
#  Synset('unresentful.a.01'),
#  Synset('unbitter.s.01'),
#  Synset('sentient.a.01'),
#  Synset('sensate.s.01'),
#  Synset('insentient.a.01'),
#  Synset('unfeeling.s.02'),
#  Synset('animate.a.02'),
#  Synset('inanimate.a.02'),
#  Synset('nonconscious.s.02'),
#  Synset('animated.a.01'),
#  Synset('enlivened.s.02'),
#  Synset('full_of_life.s.01'),
#  Synset('reanimated.s.01'),
#  Synset('unanimated.a.01'),
#  Synset('lifeless.s.03'),
#  Synset('wan.s.03'),
#  Synset('enlivened.a.01'),
#  Synset('perked_up.s.01'),
#  Synset('unenlivened.a.01'),
#  Synset('animate.a.01'),
#  Synset('inanimate.a.01'),
#  Synset('anonymous.a.01'),
#  Synset('nameless.s.01'),
#  Synset('onymous.a.01'),
#  Synset('binomial.s.02'),
#  Synset('pseudonymous.s.01'),
#  Synset('antemortem.a.01'),
#  Synset('postmortem.a.01'),
#  Synset('antecedent.a.01'),
#  Synset('anterior.s.02'),
#  Synset('anticipatory.s.01'),
#  Synset('preexistent.s.01'),
#  Synset('subsequent.a.01'),
#  Synset('attendant.s.02'),
#  Synset('later.s.01'),
#  Synset('antrorse.a.01'),
#  Synset('retrorse.a.01'),
#  Synset('decurved.s.01'),
#  Synset('aquatic.a.02'),
#  Synset('marine.s.05'),
#  Synset('semiaquatic.s.02'),
#  Synset('subaqueous.s.01'),
#  Synset('terrestrial.a.03'),
#  Synset('onshore.s.02'),
#  Synset('overland.s.01'),
#  Synset('amphibious.a.02'),
#  Synset('amphibiotic.s.01'),
#  Synset('preceding.a.01'),
#  Synset('above.s.01'),
#  Synset('above-mentioned.s.01'),
#  Synset('foregoing.s.01'),
#  Synset('introductory.s.03'),
#  Synset('precedent.s.01'),
#  Synset('premedical.s.02'),
#  Synset('preparatory.s.01'),
#  Synset('previous.s.01'),
#  Synset('succeeding.a.01'),
#  Synset('back-to-back.s.01'),
#  Synset('ensuing.s.01'),
#  Synset('following.s.01'),
#  Synset('following.s.02'),
#  Synset('in_line.s.01'),
#  Synset('postmortem.s.02'),
#  Synset('precedented.a.01'),
#  Synset('unprecedented.a.01'),
#  Synset('new.s.04'),
#  Synset('prehensile.a.01'),
#  Synset('nonprehensile.a.01'),
#  Synset('prenatal.a.01'),
#  Synset('perinatal.a.01'),
#  Synset('postnatal.a.01'),
#  Synset('preprandial.a.01'),
#  Synset('postprandial.a.01'),
#  Synset('prewar.a.01'),
#  Synset('postwar.a.01'),
#  Synset('retrograde.a.02'),
#  Synset('anterograde.a.01'),
#  Synset('antemeridian.a.01'),
#  Synset('ante_meridiem.s.01'),
#  Synset('postmeridian.a.01'),
#  Synset('post_meridiem.s.01'),
#  Synset('anterior.a.01'),
#  Synset('frontal.s.01'),
#  Synset('frontal.s.04'),
#  Synset('prefrontal.s.01'),
#  Synset('posterior.a.01'),
#  Synset('back.s.02'),
#  Synset('caudal.s.03'),
#  Synset('retral.s.02'),
#  Synset('dorsal.a.01'),
#  Synset('ventral.a.01'),
#  Synset('dorsoventral.s.01'),
#  Synset('appealable.a.01'),
#  Synset('unappealable.a.01'),
#  Synset('appendaged.a.01'),
#  Synset('unappendaged.a.01'),
#  Synset('appetizing.a.01'),
#  Synset('mouth-watering.s.01'),
#  Synset('unappetizing.a.01'),
#  Synset('approachable.a.02'),
#  Synset('accessible.s.04'),
#  Synset('unapproachable.a.01'),
#  Synset('offish.s.01'),
#  Synset('appropriate.a.01'),
#  Synset('befitting.s.01'),
#  Synset('grade-appropriate.s.01'),
#  Synset('pat.s.02'),
#  Synset('proper.s.04'),
#  Synset('inappropriate.a.01'),
#  Synset('unbefitting.s.01'),
#  Synset('improper.s.03'),
#  Synset('due.a.01'),
#  Synset('callable.s.01'),
#  Synset('collect.s.01'),
#  Synset('collectible.s.01'),
#  Synset('delinquent.s.03'),
#  Synset('receivable.s.01'),
#  Synset('out-of-pocket.s.01'),
#  Synset('repayable.s.01'),
#  Synset('undue.a.01'),
#  Synset('due.a.03'),
#  Synset('undue.a.02'),
#  Synset('apropos.a.01'),
#  Synset('apposite.s.01'),
#  Synset('malapropos.a.01'),
#  Synset('inapposite.s.01'),
#  Synset('a_priori.a.01'),
#  Synset('a_posteriori.a.01'),
#  Synset('apteral.a.01'),
#  Synset('amphiprostylar.s.01'),
#  Synset('prostyle.s.01'),
#  Synset('peripteral.a.01'),
#  Synset('monopteral.s.01'),
#  Synset('peristylar.s.01'),
#  Synset('arbitrable.a.01'),
#  Synset('nonarbitrable.a.01'),
#  Synset('columned.a.01'),
#  Synset('amphistylar.s.01'),
#  Synset('columnar.s.02'),
#  Synset('columniform.s.01'),
#  Synset('colonnaded.s.01'),
#  Synset('pillared.s.01'),
#  Synset('noncolumned.a.01'),
#  Synset('astylar.s.01'),
#  Synset('unpillared.s.01'),
#  Synset('arboreal.a.02'),
#  Synset('nonarboreal.a.01'),
#  Synset('arenaceous.a.01'),
#  Synset('argillaceous.a.01'),
#  Synset('armed.a.01'),
#  Synset('equipped.s.04'),
#  Synset('light-armed.s.02'),
#  Synset('militarized.s.01'),
#  Synset('unarmed.a.01'),
#  Synset('barehanded.s.01'),
#  Synset('clean.s.16'),
#  Synset('defenseless.s.03'),
#  Synset('weaponless.s.01'),
#  Synset('armored.a.01'),
#  Synset('armor-clad.s.01'),
#  Synset('bony-plated.s.01'),
#  Synset('bulletproof.s.02'),
#  Synset('lightly_armored.s.01'),
#  Synset('mail-cheeked.s.01'),
#  Synset('mail-clad.s.01'),
#  Synset('scaled.s.02'),
#  Synset('unarmored.a.02'),
#  Synset('armed.a.03'),
#  Synset('barbed.s.02'),
#  Synset('bristlelike.s.01'),
#  Synset('brushlike.s.01'),
#  Synset('thistlelike.s.01'),
#  Synset('clawed.s.02'),
#  Synset('unarmed.a.02'),
#  Synset('thornless.s.01'),
#  Synset('armed.a.02'),
#  Synset('armlike.s.01'),
#  Synset('brachiate.s.02'),
#  Synset('long-armed.s.01'),
#  Synset('one-armed.s.01'),
#  Synset('armless.a.01'),
#  Synset('armored.a.02'),
#  Synset('bone-covered.s.01'),
#  Synset('scaly.s.02'),
#  Synset('silver-scaled.s.01'),
#  Synset('unarmored.a.01'),
#  Synset('scaleless.s.01'),
#  Synset('artful.a.02'),
#  Synset('crafty.s.01'),
#  Synset('cute.s.02'),
#  Synset('designing.s.01'),
#  Synset('deep.s.15'),
#  Synset('elusive.s.02'),
#  Synset('manipulative.s.01'),
#  Synset('pawky.s.01'),
#  Synset('artless.a.02'),
#  Synset('careless.s.02'),
#  Synset('articulate.a.01'),
#  Synset('eloquent.s.01'),
#  Synset('speech-endowed.s.01'),
#  Synset('well-spoken.s.01'),
#  Synset('inarticulate.a.01'),
#  Synset('aphasic.s.02'),
#  Synset('aphonic.s.01'),
#  Synset('dumb.s.04'),
#  Synset('dumb.s.03'),
#  Synset('incoherent.s.03'),
#  Synset('mute.s.01'),
#  Synset('speechless.s.01'),
#  Synset('unarticulated.s.02'),
#  Synset('speaking.a.01'),
#  Synset('tongued.s.02'),
#  Synset('nonspeaking.a.01'),
#  Synset('articulated.a.01'),
#  Synset('jointed.s.01'),
#  Synset('unarticulated.a.01'),
#  Synset('unjointed.s.01'),
#  Synset('ashamed.a.01'),
#  Synset('discredited.s.02'),
#  Synset('embarrassed.s.02'),
#  Synset('guilty.s.02'),
#  Synset('shamefaced.s.02'),
#  Synset('unashamed.a.01'),
#  Synset('audacious.s.02'),
#  Synset('shameless.s.01'),
#  Synset('unabashed.s.01'),
#  Synset('assertive.a.01'),
#  Synset('cocky.s.01'),
#  Synset('emphatic.s.03'),
#  Synset('unassertive.a.01'),
#  Synset('nonassertive.s.01'),
#  Synset('reticent.s.03'),
#  Synset('associative.a.01'),
#  Synset('associable.s.01'),
#  Synset('nonassociative.a.01'),
#  Synset('attached.a.03'),
#  Synset('bespoken.s.02'),
#  Synset('intended.s.02'),
#  Synset('involved.s.03'),
#  Synset('unattached.a.02'),
#  Synset('unengaged.s.02'),
#  Synset('affixed.a.01'),
#  Synset('appendant.s.01'),
#  Synset('basifixed.s.01'),
#  Synset('glued.s.01'),
#  Synset('mounted.s.01'),
#  Synset('unaffixed.a.01'),
#  Synset('sessile.a.02'),
#  Synset('pedunculate.a.01'),
#  Synset('sessile.a.01'),
#  Synset('vagile.a.01'),
#  Synset('free-swimming.s.01'),
#  Synset('attached.a.02'),
#  Synset('detached.a.04'),
#  Synset('freestanding.s.01'),
#  Synset('semidetached.s.01'),
#  Synset('stuck.a.01'),
#  Synset('cragfast.s.01'),
#  Synset('unstuck.a.01'),
#  Synset('attachable.a.01'),
#  Synset('bindable.s.01'),
#  Synset('clip-on.s.01'),
#  Synset('tie-on.s.01'),
#  Synset('detachable.a.01'),
#  Synset('clastic.s.02'),
#  Synset('wary.a.01'),
#  Synset('on_guard.s.01'),
#  Synset('shy.s.03'),
#  Synset('unwary.a.01'),
#  Synset('gullible.s.02'),
#  Synset('unguarded.s.02'),
#  Synset('attentive.a.01'),
#  Synset('captive.s.02'),
#  Synset('advertent.s.01'),
#  Synset('observant.s.01'),
#  Synset('oversolicitous.s.01'),
#  Synset('solicitous.s.02'),
#  Synset('inattentive.a.01'),
#  Synset('absent.s.03'),
#  Synset('distracted.s.01'),
#  Synset('dreamy.s.01'),
#  Synset('drowsy.s.02'),
#  Synset('forgetful.s.03'),
#  Synset('attractive.a.01'),
#  Synset('bewitching.s.01'),
#  Synset('charismatic.s.01'),
#  Synset('cunning.s.01'),
#  Synset('dinky.s.02'),
#  Synset('engaging.s.01'),
#  Synset('fetching.s.01'),
#  Synset('glossy.s.03'),
#  Synset('hypnotic.s.02'),
#  Synset('irresistible.s.02'),
#  Synset('personable.s.01'),
#  Synset('photogenic.s.01'),
#  Synset('prepossessing.s.01'),
#  Synset('winsome.s.01'),
#  Synset('unattractive.a.01'),
#  Synset('homely.s.01'),
#  Synset('subfusc.s.01'),
#  Synset('unprepossessing.s.01'),
#  Synset('attractive.a.03'),
#  Synset('repulsive.a.02'),
#  Synset('appealing.a.01'),
#  Synset('attention-getting.s.02'),
#  Synset('attractive.s.02'),
#  Synset('unappealing.a.02'),
#  Synset('off-putting.s.02'),
#  Synset('unattractive.s.02'),
#  Synset('attributable.a.01'),
#  Synset('ascribable.s.01'),
#  Synset('credited.s.01'),
#  Synset('traceable.s.01'),
#  Synset('unattributable.a.01'),
#  Synset('attributive.a.01'),
#  Synset('attributive_genitive.s.01'),
#  Synset('predicative.a.01'),
#  Synset('pregnant.a.01'),
#  Synset('big.s.13'),
#  Synset('nonpregnant.a.01'),
#  Synset('audible.a.01'),
#  Synset('clunky.s.02'),
#  Synset('sonic.s.02'),
#  Synset('sounding.s.03'),
#  Synset('inaudible.a.01'),
#  Synset('breathed.s.01'),
#  Synset('infrasonic.s.01'),
#  Synset('silent.s.05'),
#  Synset('silent.s.04'),
#  Synset('supersonic.s.02'),
#  Synset('unheard.s.01'),
#  Synset('sonic.a.01'),
#  Synset('subsonic.a.01'),
#  Synset('supersonic.a.01'),
#  Synset('auspicious.a.01'),
#  Synset('bright.s.10'),
#  Synset('fortunate.s.03'),
#  Synset('inauspicious.a.01'),
#  Synset('unpromising.s.01'),
#  Synset('propitious.a.01'),
#  Synset('golden.s.06'),
#  Synset('gracious.s.04'),
#  Synset('unpropitious.a.01'),
#  Synset('ill.s.05'),
#  Synset('thunderous.s.02'),
#  Synset('authorized.a.01'),
#  Synset('accredited.s.01'),
#  Synset('approved.s.01'),
#  Synset('canonized.s.01'),
#  Synset('empowered.s.01'),
#  Synset('unauthorized.a.01'),
#  Synset('self-appointed.s.01'),
#  Synset('unaccredited.s.01'),
#  Synset('constitutional.a.02'),
#  Synset('unconstitutional.a.01'),
#  Synset('autochthonous.a.01'),
#  Synset('allochthonous.a.01'),
#  Synset('autoecious.a.01'),
#  Synset('heteroecious.a.01'),
#  Synset('autogenous.a.01'),
#  Synset('self-generated.s.02'),
#  Synset('self-induced.s.02'),
#  Synset('heterogenous.a.02'),
#  Synset('automatic.a.01'),
#  Synset('autoloading.s.01'),
#  Synset('automated.s.01'),
#  Synset('self-acting.s.01'),
#  Synset('self-locking.s.01'),
#  Synset('self-winding.s.01'),
#  Synset('semiautomatic.s.01'),
#  Synset('smart.s.07'),
#  Synset('manual.a.02'),
#  Synset('hand-operated.s.01'),
#  Synset('available.a.01'),
#  Synset('accessible.s.03'),
#  Synset('acquirable.s.01'),
#  Synset('addressable.s.01'),
#  Synset('easy.s.11'),
#  Synset('forthcoming.s.03'),
#  Synset('gettable.s.01'),
#  Synset('in_stock.s.01'),
#  Synset('lendable.s.01'),
#  Synset('visible.s.03'),
#  Synset('on_hand.s.01'),
#  ...]

# %% [markdown]
# ## 2. 关系存储为CSV文件

# %% [markdown]
# ## 3. CSV导入Neo4j及可视化效果

# %% [markdown]
# ## 4. CSV导入Nebula及可视化效果
